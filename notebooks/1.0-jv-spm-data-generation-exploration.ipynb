# %% [markdown]
# ## Data Generation for Convolutional-Autoencoder
#
# Generamos datos sintéticos de firmas polarimétricas provenientes de superficies rugosas. Las mismas se simulan bajo la aproximación SPM de segundo orden, considerando un _stack_ de dos capas rugosas como suelo a incidir.
#
# Luego visualizamos y exploramos la distribución de los datos, y sus características.

# %% [markdown]
# ### 1 - Generación de datos sin ruido

# %% [markdown]
# Comenzamos importando los módulos que vamos a utilizar en el notebook

# %%
import numpy as np
from matplotlib import pyplot as plt

from deep_scattering_models.data.create_data import make_data, save_data, load_data
from deep_scattering_models.visualization.visualize import plot_polarization_signature, plot_histogram
from deep_scattering_models.features.preprocess_data import to_dB

# %% [markdown]
# Generamos 20048 firmas polarimétricas de $45x90$. El espacio de parámetros sobre el que se samplea puede consultarse en la documentación de la función ``create_data.init_parameters_grid``.
#
# Luego guardamos los como un solo ndarray en la carpeta data del repositorio.

# %%
# Generamos los datos
data = make_data()

# Guardamos los datos en data
file_name = "raw/spm_signatures_no_noise"
save_data(file_name, data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4879/2029532279.py in <module>
#       1 # Generamos los datos
# ----> 2 data = make_data()
#       3
#       4 # Guardamos los datos en data
#       5 file_name = "raw/spm_signatures_no_noise"
#
# ~/proyectos/tesis/src/deep_scattering_models/data/create_data.py in make_data(realizations, noise, size, **kwargs)
#     146         surface = SpmSurface(**surf_parameters)
#     147         try:
# --> 148             signature = surface.polarization_signature(
#     149                 lambda_,
#     150                 theta,
#
# ~/proyectos/tesis/src/deep_scattering_models/small_perturbation_method/t_matrix.py in polarization_signature(self, lambda_, theta_inc, phi_inc, grid_size, second_order, wishard_noise, **int_kw)
#     822
#     823         # Mueller matrix
# --> 824         m_matrix = self.mueller_matrix(
#     825             lambda_,
#     826             theta_inc,
#
# ~/proyectos/tesis/src/deep_scattering_models/small_perturbation_method/t_matrix.py in mueller_matrix(self, lambda_, theta_inc, phi_inc, second_order, noise, **int_kw)
#     723
#     724         # Coherence T-Matrix
# --> 725         T = self.t_matrix(
#     726             lambda_,
#     727             theta_inc,
#
# ~/proyectos/tesis/src/deep_scattering_models/small_perturbation_method/t_matrix.py in t_matrix(self, lambda_, theta_inc, phi_inc, second_order, noise, **int_kw)
#     636         # Add second order terms
#     637         if second_order:
# --> 638             amps_dict = self._spm2_integration(
#     639                 lambda_, theta_inc, phi_inc, **int_kw
#     640                 )
#
# ~/proyectos/tesis/src/deep_scattering_models/small_perturbation_method/t_matrix.py in _spm2_integration(self, lambda_, theta_inc, phi_inc, n, lim)
#     519
#     520         # Scattering amplitudes
# --> 521         amps_dict = self._spm2_s_matrix(lambda_, theta_inc, phi_inc, n, lim)
#     522
#     523         S_hh, S_vv, S_hh_S_vv = amps_dict['co-pol']
#
# ~/proyectos/tesis/src/deep_scattering_models/small_perturbation_method/t_matrix.py in _spm2_s_matrix(self, lambda_, theta_inc, phi_inc, n, lim)
#     383
#     384         # Second term (evaluated on k - k_i - k')
# --> 385         amps_st = self._spm2_amplitudes(
#     386             lambda_, theta_inc, phi_inc,
#     387             (k_sx + k_x - kr_x, k_sy + k_y - kr_y)
#
# ~/proyectos/tesis/src/deep_scattering_models/small_perturbation_method/t_matrix.py in _spm2_amplitudes(self, lambda_, theta_inc, phi_inc, int_arguments)
#     217             # Interaction between layers
#     218             # Co-pol amplitudes
# --> 219             f12_hh = L1_12HH(x, y, k, theta_s, phi_s, theta_inc,
#     220                         phi_inc, self.ep_1, self.ep_2, self.d)
#     221
#
# ~/proyectos/tesis/src/deep_scattering_models/small_perturbation_method/spm2.py in L1_12HH(sx, sy, k0, th, ph, thi, phi, ep1, ep2, d)
#     904             k0*kx(k0,th,ph)*q4TE_F2(sx,sy,k0,th,ph,thi,phi,ep1,ep2,d))+exp(2*1j*d*k1z(k0,th,ep1))*(k1z(k0,th,ep1)-k2z(k0,th,ep2))*(k1z(k0,th,ep1)*kx(k0,th,ph)*q1TE_F2(sx,sy,k0,th,ph,thi,phi,ep1,ep2,d)+\
#     905             k1z(k0,th,ep1)*ky(k0,th,ph)*q2TE_F2(sx,sy,k0,th,ph,thi,phi,ep1,ep2,d) + k0*(ky(k0,th,ph)*q3TE_F2(sx,sy,k0,th,ph,thi,phi,ep1,ep2,d) - kx(k0,th,ph)*q4TE_F2(sx,sy,k0,th,ph,thi,phi,ep1,ep2,d)))-\
# --> 906              2*exp(1j*d*k1z(k0,th,ep1))*k1z(k0,th,ep1)*(k2z(k0,th,ep2)*kx(k0,th,ph)*q5TE_F1(sx,sy,k0,th,ph,thi,phi,ep1,ep2,d) + k2z(k0,th,ep1)*ky(k0,th,ph)*q6TE_F1(sx,sy,k0,th,ph,thi,phi,ep1,ep2,d) - k0*ky(k0,th,ph)*q7TE_F1(sx,sy,k0,th,ph,thi,phi,ep1,ep2,d)+\
#     907              k0*kx(k0,th,ph)*q8TE_F1(sx,sy,k0,th,ph,thi,phi,ep1,ep2,d))))/((exp(2*1j*d*k1z(k0,th,ep1))*(k0z(k0,th) - k1z(k0,th,ep1))*(k1z(k0,th,ep1) - k2z(k0,th,ep2)) + (k0z(k0,th) + k1z(k0,th,ep1))*(k1z(k0,th,ep1) + k2z(k0,th,ep2)))*(kx(k0,th,ph)**2 + ky(k0,th,ph)**2)))
#     908
#
# ~/proyectos/tesis/src/deep_scattering_models/small_perturbation_method/spm2.py in q5TE_F1(sx, sy, k0, th, ph, thi, phi, ep1, ep2, d)
#     522
#     523 def q5TE_F1(sx,sy,k0,th,ph,thi,phi,ep1,ep2,d):
# --> 524     return L15TE + Y5TE_F1(sx,sy,k0,th,ph,thi,phi,ep1,ep2,d)
#     525
#     526
#
# ~/proyectos/tesis/src/deep_scattering_models/small_perturbation_method/spm2.py in Y5TE_F1(sx, sy, k0, th, ph, thi, phi, ep1, ep2, d)
#     517 #--F1
#     518 def Y5TE_F1(sx,sy,k0,th,ph,thi,phi,ep1,ep2,d):
# --> 519     return 1j*exp(1j*d*s1z(k0,sx,sy,ep1))*s1z(k0,sx,sy,ep1)*((b1HHF1(k0,thi,phi,th,ph,ep1,ep2,d)*sx)/sr(sx,sy) - (b1VHF1(k0,thi,phi,th,ph,ep1,ep2,d)*s1z(k0,sx,sy,ep1)*sy)/(k0*sr(sx,sy)*sqrt(ep1))) - (1j*s1z(k0,sx,sy,ep1)*((bb1HHF1(k0,thi,phi,th,ph,ep1,ep2,d)*sx)/sr(sx,sy) + (bb1VHF1(k0,thi,phi,th,ph,ep1,ep2,d)*s1z(k0,sx,sy,ep1)*sy)/(k0*sr(sx,sy)*sqrt(ep1))))/exp(1j*d*s1z(k0,sx,sy,ep1))+\
#     520             (1j*(bb1VHF1(k0,thi,phi,th,ph,ep1,ep2,d)/exp(1j*d*s1z(k0,sx,sy,ep1)) + b1VHF1(k0,thi,phi,th,ph,ep1,ep2,d)*exp(1j*d*s1z(k0,sx,sy,ep1)))*(ky(k0,th,ph) - sy)*sr(sx,sy))/(k0*sqrt(ep1)) - 1j*exp(1j*d*s2z(k0,sx,sy,ep2))*s2z(k0,sx,sy,ep2)*((c1HHF1(k0,thi,phi,th,ph,ep1,ep2,d)*sx)/sr(sx,sy) - (c1VHF1(k0,thi,phi,th,ph,ep1,ep2,d)*s2z(k0,sx,sy,ep2)*sy)/(k0*sr(sx,sy)*sqrt(ep2)))-\
#     521             (1j*c1VHF1(k0,thi,phi,th,ph,ep1,ep2,d)*exp(1j*d*s2z(k0,sx,sy,ep2))*(ky(k0,th,ph) - sy)*sr(sx,sy))/(k0*sqrt(ep2))
#
# ~/proyectos/tesis/src/deep_scattering_models/small_perturbation_method/spm2.py in b1VHF1(k0, thi, phi, th, ph, ep1, ep2, d)
#     245 def b1VHF1(k0,thi,phi,th,ph,ep1,ep2,d):
#     246     return  -1j*(((kiy(k0,thi,phi)*kx(k0,th,ph) - kix(k0,thi,phi)*ky(k0,th,ph))*kr(k0,th)*(bb0HH(k0,thi,ep1,ep2,d)*exp(1j*d*k1zi(k0,thi,ep1))*(k1zi(k0,thi,ep1)*sqrt(ep1) - k0z(k0,th)*(k1z(k0,th,ep1)**2 + kir(k0,thi)**2)*sqrt(ep1))*sqrt(ep2)*(k2z(k0,th,ep2)*ep1 + k1z(k0,th,ep1)*ep2) - \
# --> 247             b0HH(k0,thi,ep1,ep2,d)*exp(1j*d*k1zi(k0,thi,ep1))*(k1zi(k0,thi,ep1)*sqrt(ep1) + k0z(k0,th)*(k1zi(k0,thi,ep1)**2 + kir(k0,thi)**2)*sqrt(ep1))*sqrt(ep2)*(k2z(k0,th,ep2)*ep1 + k1z(k0,th,ep1)*ep2) - \
#     248             exp(1j*d*k1zi(k0,thi,ep1))*((-1 + a0HH(k0,thi,ep1,ep2,d))*kiz(k0,thi) - (1 + a0HH(k0,thi,ep1,ep2,d))*k0z(k0,th)*(kiz(k0,thi)**2 + kir(k0,thi)**2))*sqrt(ep1)*sqrt(ep2)*(k2z(k0,th,ep2)*ep1 + k1z(k0,th,ep1)*ep2)))/\
#     249             (exp(1j*d*k1zi(k0,thi,ep1))*kir(k0,thi)*(kx(k0,th,ph)**2 + ky(k0,th,ph)**2)*sqrt(ep2)*(exp(2*1j*d*k1z(k0,th,ep1))*(k1z(k0,th,ep1) - k0z(k0,th)*ep1)*(k2z(k0,th,ep2)*ep1 - k1z(k0,th,ep1)*ep2) + (k1z(k0,th,ep1) + k0z(k0,th)*ep1)*(k2z(k0,th,ep2)*ep1 + k1z(k0,th,ep1)*ep2))))
#
# ~/proyectos/tesis/src/deep_scattering_models/small_perturbation_method/spm2.py in b0HH(k0, thi, ep1, ep2, d)
#      90
#      91 def b0HH(k0,thi,ep1,ep2,d):
# ---> 92     return (-2*(k1zi(k0,thi,ep1) + k2zi(k0,thi,ep2))*kiz(k0,thi))/(exp(2*1j*d*k1zi(k0,thi,ep1))*(k1zi(k0,thi,ep1) - k2zi(k0,thi,ep2))*(k1zi(k0,thi,ep1) - kiz(k0,thi)) - (k1zi(k0,thi,ep1) + k2zi(k0,thi,ep2))*(k1zi(k0,thi,ep1) + kiz(k0,thi)))
#      93
#      94 def c0HH(k0,thi,ep1,ep2,d):
#
# ~/proyectos/tesis/src/deep_scattering_models/small_perturbation_method/spm2.py in kiz(k0, thi)
#      15 #onda incidente
#      16 def kiz(k0,thi):
# ---> 17     return k0*cos(thi)
#      18
#      19 def kix(k0,thi,phi):
#
# KeyboardInterrupt:

# %%
data = load_data(file_name)

# %% [markdown]
# Veamos la pinta de alguna de las firmas polarimétricas generadas

# %%
# Elegimos una firma al azar
rng = np.random.default_rng()
rnd_index = rng.integers(1024)
rnd_signature = data[rnd_index, :, :]

# Ploteamos
plot_polarization_signature(rnd_signature)
# Out:
# <AxesSubplot:title={'center':'$\\sigma(\\psi,\\chi)$'}, xlabel='Orientation Angle $\\psi$ [°]', ylabel='Ellipticity Angle $\\chi$ [°]'>

# %% [markdown]
# ### 2 - Exploración de los Datos

# %% [markdown]
# Veamos cual es la distribución de los datos en crudo

# %%
plot_histogram(data)
# Out:
# <AxesSubplot:title={'center':'Polarization Signature values distribution'}, xlabel='$\\sigma(\\psi, \\chi)$', ylabel='Count'>

# %% [markdown]
# Pasemos los datos a dB, y volvamos a ver qué forma tiene su histograma

# %%
data_dB = to_dB(data)
ax = plot_histogram(data_dB)
ax.set_xlabel(r"$\sigma(\psi, \chi)$ [dB]")

# %%
# Elegimos ana firma al azar
rng = np.random.default_rng()
rnd_index = rng.integers(1024)
rnd_signature = data_dB[rnd_index, :, :]

# Ploteamos
plot_polarization_signature(rnd_signature)
# Out:
# <AxesSubplot:title={'center':'$\\sigma(\\psi,\\chi)$'}, xlabel='Orientation Angle $\\psi$ [°]', ylabel='Ellipticity Angle $\\chi$ [°]'>

# %% [markdown]
# ### 3 - Datos con ruido
#
# Generamos nuevos datos con ruido de distribución wishart agregado [[1]](https://en.wikipedia.org/wiki/Wishart_distribution), los visualizamos y analizamos sus distribuciones en potencia y en dB.

# %%
# Generamos los datos
noised_data = make_data(noise=True)

# Guardamos los datos en data
file_name = "raw/spm_signatures"
save_data(file_name, noised_data)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# File ~/proyects/tesis/src/deep_scattering_models/data/create_data.py:148, in make_data(realizations, noise, size, **kwargs)
#     147 try:
# --> 148     signature = surface.polarization_signature(
#     149         lambda_,
#     150         theta,
#     151         phi,
#     152         wishard_noise=noise,
#     153         grid_size=size
#     154     )
#     155 except scipy.linalg.LinAlgError:
#
# File ~/proyects/tesis/src/deep_scattering_models/small_perturbation_method/t_matrix.py:793, in SpmSurface.polarization_signature(self, lambda_, theta_inc, phi_inc, grid_size, second_order, wishard_noise, **int_kw)
#     792 if wishard_noise:
# --> 793     m_matrix = cwishrnd(m_matrix)
#     795 # Grid Size
#
# File ~/proyects/tesis/src/deep_scattering_models/utils.py:33, in cwishrnd(M, looks_num)
#      29 #elif not(np.allclose(M, np.matrix(M).H, rtol=1e-05, atol=1e-08)):
#      30 #    raise ValueError('M must be hermitian')
#      31
#      32 # Cholesky Decomposition and ...
# ---> 33 d = np.linalg.cholesky(M)
#      35 if (looks_num <= MAX_LOOKS + n):
#      36     # Random defaul Generator and random matrix
#
# File <__array_function__ internals>:180, in cholesky(*args, **kwargs)
#
# File ~/proyects/tesis/lib/python3.8/site-packages/numpy/linalg/linalg.py:763, in cholesky(a)
#     762 signature = 'D->D' if isComplexType(t) else 'd->d'
# --> 763 r = gufunc(a, signature=signature, extobj=extobj)
#     764 return wrap(r.astype(result_t, copy=False))
#
# File ~/proyects/tesis/lib/python3.8/site-packages/numpy/linalg/linalg.py:91, in _raise_linalgerror_nonposdef(err, flag)
#      90 def _raise_linalgerror_nonposdef(err, flag):
# ---> 91     raise LinAlgError("Matrix is not positive definite")
#
# LinAlgError: Matrix is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In [2], line 2
#       1 # Generamos los datos
# ----> 2 noised_data = make_data(noise=True)
#       4 # Guardamos los datos en data
#       5 file_name = "raw/spm_signatures"
#
# File ~/proyects/tesis/src/deep_scattering_models/data/create_data.py:156, in make_data(realizations, noise, size, **kwargs)
#     148     signature = surface.polarization_signature(
#     149         lambda_,
#     150         theta,
#    (...)
#     153         grid_size=size
#     154     )
#     155 except scipy.linalg.LinAlgError:
# --> 156     raise(ValueError("La Matriz de Mueller no satisface las hipótesis "
#     157     f"de Cholesky para los parámetros \n {surf_parameters}"))
#     159 else:
#     160     # Stack result in data
#     161     data[i, :, :] = np.real(signature)
#
# ValueError: La Matriz de Mueller no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.004, 'corr_length': 0.05647058823529411, 'epsilon': 23, 'epsilon_2': 4, 'rms_high_2': 0.011294117647058823, 'corr_length_2': 0.033882352941176475, 'distance': 0.2411764705882353, 'two_layer': True}

# %%
noised_data = load_data("raw/spm_signatures")

# %% [markdown]
# Nuevamente, elijamos una firma al azar y veamos qué pinta tiene.

# %%
# Elegimos ana firma al azar
rng = np.random.default_rng()
rnd_index = rng.integers(20048)
rnd_signature = noised_data[rnd_index, :, :]

# Ploteamos
plot_polarization_signature(rnd_signature)
# Out:
# <AxesSubplot:title={'center':'$\\sigma(\\psi,\\chi)$'}, xlabel='Orientation Angle $\\psi$ [°]', ylabel='Ellipticity Angle $\\chi$ [°]'>

# %% [markdown]
# Transformemos a dB y miremos la distribución de los datos, que no debería cambiar por el agregado de ruido.

# %%
noised_data_dB = to_dB(noised_data)
ax = plot_histogram(noised_data_dB)
ax.set_xlabel(r"$\sigma(\psi, \chi)$ [dB]")

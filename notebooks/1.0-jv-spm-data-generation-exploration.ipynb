# %% [markdown]
# ## Data Generation for Convolutional-Autoencoder
#
# Generamos datos sintéticos de firmas polarimétricas provenientes de superficies rugosas. Las mismas se simulan bajo la aproximación SPM de segundo orden, considerando un _stack_ de dos capas rugosas como suelo a incidir.
#
# Luego visualizamos y exploramos la distribución de los datos, y sus características.

# %% [markdown]
# ### 1 - Generamos datos sin ruido

# %% [markdown]
# Comenzamos importando los módulos que vamos a utilizar en el notebook

# %%
import numpy as np
from matplotlib import pyplot as plt

from deep_scattering_models.data.create_data import make_data, save_data, load_data
from deep_scattering_models.visualization.visualize import plot_polarization_signature, plot_histogram
from deep_scattering_models.features.preprocess_data import to_dB, remove_outliers

# %% [markdown]
# Generamos 20048 firmas polarimétricas de $45x90$. El espacio de parámetros sobre el que se samplea puede consultarse en la documentación de la función ``create_data.init_parameters_grid``.
#
# Luego guardamos los como un solo ndarray en la carpeta data del repositorio.

# %%
# Generamos los datos
data = make_data()

# Guardamos los datos en data
file_name = "raw/spm_signatures_no_noise"
save_data(file_name, data)
# Out:
# Data saved at /home/jotavecorta/proyects/DeepScatteringModels/data/spm/raw/spm_signatures_no_noise.npy

# %%
data = load_data(file_name)

# %% [markdown]
# Veamos la pinta de alguna de las firmas polarimétricas generadas

# %%
# Elegimos una firma al azar
rng = np.random.default_rng()
rnd_index = rng.integers(data.shape[0])
rnd_signature = data[rnd_index, :, :]

# Ploteamos
plot_polarization_signature(rnd_signature)
# Out:
# <AxesSubplot:title={'center':'$\\sigma(\\psi,\\chi)$'}, xlabel='Orientation Angle $\\psi$ [°]', ylabel='Ellipticity Angle $\\chi$ [°]'>

# %% [markdown]
# ### 2 - Exploración de los Datos

# %% [markdown]
# Veamos cual es la distribución de los datos en crudo

# %%
plot_histogram(data, n_bins=100, hist_kw={"range":(-0.01, 0.01)})
# Out:
# <AxesSubplot:title={'center':'Polarization Signature values distribution'}, xlabel='$\\sigma(\\psi, \\chi)$', ylabel='Count'>

# %%
print(f"Valor máximo de potencia: {data.max()}")
print(f"Valor mínimo de potencia: {data.min()}")
# Out:
# Valor máximo de potencia: 369119927674193.2
# Valor mínimo de potencia: -1570809413330378.2

# %%
new_data = remove_outliers(data, k=300)
print(f"Muestras luego de remover outliers: {new_data.shape[0]}")
# Out:
# Muestras luego de remover outliers: 6219

# %%
plot_histogram(new_data, hist_kw={"range":(-0.01, 0.01)})
# Out:
# <AxesSubplot:title={'center':'Polarization Signature values distribution'}, xlabel='$\\sigma(\\psi, \\chi)$', ylabel='Count'>

# %%
print(f"Valor máximo de potencia: {new_data.max()}")
print(f"Valor mínimo de potencia: {new_data.min()}")
# Out:
# Valor máximo de potencia: 0.10270414946516299
# Valor mínimo de potencia: -7.643416837876766e-10

# %% [markdown]
# Pasemos los datos a dB, y volvamos a ver qué forma tiene su histograma

# %%
def to_dB(data):
    # Replace zeros to take log    
    no_zeros_data = np.where(data>0.0, data, data[data>0.0].min())
    
    return 10*np.log10(no_zeros_data)
    
data_dB = to_dB(new_data)
ax = plot_histogram(data_dB, hist_kw={"range":(-125, -10)})
ax.set_xlabel(r"$\sigma(\psi, \chi)$ [dB]")
# Out:
# Text(0.5, 0, '$\\sigma(\\psi, \\chi)$ [dB]')

# %%
# Elegimos ana firma al azar
rng = np.random.default_rng()
rnd_index = rng.integers(new_data.shape[0])
rnd_signature = data_dB[rnd_index, :, :]

# Ploteamos
plot_polarization_signature(rnd_signature)
# Out:
# <AxesSubplot:title={'center':'$\\sigma(\\psi,\\chi)$'}, xlabel='Orientation Angle $\\psi$ [°]', ylabel='Ellipticity Angle $\\chi$ [°]'>

# %% [markdown]
# ### 3 - Datos con ruido
#
# Generamos nuevos datos con ruido de distribución wishart agregado [[1]](https://en.wikipedia.org/wiki/Wishart_distribution), los visualizamos y analizamos sus distribuciones en potencia y en dB.

# %%
# Generamos los datos
noise_data = make_data(noise=True)

# Guardamos los datos en data
file_name = "raw/spm_signatures_noise"
save_data(file_name, noise_data)
# Out:
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.004, 'corr_length': 0.05647058823529411, 'epsilon': 23, 'epsilon_2': 4, 'rms_high_2': 0.011294117647058823, 'corr_length_2': 0.033882352941176475, 'distance': 0.2411764705882353, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.005411764705882353, 'corr_length': 0.03952941176470588, 'epsilon': 9, 'epsilon_2': 15, 'rms_high_2': 0.010588235294117648, 'corr_length_2': 0.0451764705882353, 'distance': 0.6647058823529411, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.0075294117647058826, 'corr_length': 0.03670588235294118, 'epsilon': 30, 'epsilon_2': 31, 'rms_high_2': 0.011058823529411765, 'corr_length_2': 0.06776470588235294, 'distance': 0.1, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.008, 'corr_length': 0.03670588235294118, 'epsilon': 11, 'epsilon_2': 17, 'rms_high_2': 0.010588235294117648, 'corr_length_2': 0.062117647058823534, 'distance': 0.2235294117647059, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.00988235294117647, 'corr_length': 0.031058823529411767, 'epsilon': 25, 'epsilon_2': 18, 'rms_high_2': 0.011529411764705882, 'corr_length_2': 0.059294117647058824, 'distance': 0.2411764705882353, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.010823529411764706, 'corr_length': 0.062117647058823534, 'epsilon': 10, 'epsilon_2': 21, 'rms_high_2': 0.010352941176470589, 'corr_length_2': 0.03529411764705882, 'distance': 0.2411764705882353, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.0051764705882352945, 'corr_length': 0.024, 'epsilon': 20, 'epsilon_2': 3, 'rms_high_2': 0.008705882352941178, 'corr_length_2': 0.04376470588235294, 'distance': 0.20588235294117646, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.006823529411764706, 'corr_length': 0.024, 'epsilon': 8, 'epsilon_2': 19, 'rms_high_2': 0.004470588235294118, 'corr_length_2': 0.059294117647058824, 'distance': 0.2411764705882353, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.011529411764705882, 'corr_length': 0.031058823529411767, 'epsilon': 24, 'epsilon_2': 21, 'rms_high_2': 0.011529411764705882, 'corr_length_2': 0.05364705882352941, 'distance': 0.6294117647058823, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.007764705882352941, 'corr_length': 0.033882352941176475, 'epsilon': 9, 'epsilon_2': 33, 'rms_high_2': 0.005647058823529412, 'corr_length_2': 0.059294117647058824, 'distance': 0.41764705882352937, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.00611764705882353, 'corr_length': 0.04376470588235294, 'epsilon': 30, 'epsilon_2': 18, 'rms_high_2': 0.011058823529411765, 'corr_length_2': 0.07058823529411765, 'distance': 0.27647058823529413, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.00823529411764706, 'corr_length': 0.049411764705882356, 'epsilon': 22, 'epsilon_2': 5, 'rms_high_2': 0.006823529411764706, 'corr_length_2': 0.05223529411764707, 'distance': 0.6647058823529411, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.0058823529411764705, 'corr_length': 0.05505882352941177, 'epsilon': 29, 'epsilon_2': 35, 'rms_high_2': 0.005411764705882353, 'corr_length_2': 0.05647058823529411, 'distance': 0.27647058823529413, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.0075294117647058826, 'corr_length': 0.024, 'epsilon': 28, 'epsilon_2': 4, 'rms_high_2': 0.007058823529411765, 'corr_length_2': 0.048, 'distance': 0.5058823529411764, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.007764705882352941, 'corr_length': 0.06494117647058824, 'epsilon': 7, 'epsilon_2': 12, 'rms_high_2': 0.00611764705882353, 'corr_length_2': 0.04235294117647059, 'distance': 0.1, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.0075294117647058826, 'corr_length': 0.04235294117647059, 'epsilon': 23, 'epsilon_2': 32, 'rms_high_2': 0.00611764705882353, 'corr_length_2': 0.04376470588235294, 'distance': 0.4, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.004470588235294118, 'corr_length': 0.05364705882352941, 'epsilon': 5, 'epsilon_2': 12, 'rms_high_2': 0.0075294117647058826, 'corr_length_2': 0.06352941176470589, 'distance': 0.29411764705882354, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.008, 'corr_length': 0.05223529411764707, 'epsilon': 29, 'epsilon_2': 16, 'rms_high_2': 0.008470588235294119, 'corr_length_2': 0.06494117647058824, 'distance': 0.3647058823529412, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.011529411764705882, 'corr_length': 0.04235294117647059, 'epsilon': 18, 'epsilon_2': 3, 'rms_high_2': 0.00823529411764706, 'corr_length_2': 0.046588235294117646, 'distance': 0.34705882352941175, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.008941176470588235, 'corr_length': 0.05082352941176471, 'epsilon': 36, 'epsilon_2': 17, 'rms_high_2': 0.0075294117647058826, 'corr_length_2': 0.06352941176470589, 'distance': 0.38235294117647056, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.0058823529411764705, 'corr_length': 0.049411764705882356, 'epsilon': 20, 'epsilon_2': 17, 'rms_high_2': 0.00823529411764706, 'corr_length_2': 0.05223529411764707, 'distance': 0.6823529411764706, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.004470588235294118, 'corr_length': 0.06776470588235294, 'epsilon': 20, 'epsilon_2': 16, 'rms_high_2': 0.008941176470588235, 'corr_length_2': 0.029647058823529412, 'distance': 0.5588235294117647, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.004705882352941177, 'corr_length': 0.0451764705882353, 'epsilon': 10, 'epsilon_2': 13, 'rms_high_2': 0.007764705882352941, 'corr_length_2': 0.024, 'distance': 0.6470588235294117, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.01011764705882353, 'corr_length': 0.07058823529411765, 'epsilon': 5, 'epsilon_2': 9, 'rms_high_2': 0.008, 'corr_length_2': 0.06494117647058824, 'distance': 0.27647058823529413, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.006352941176470589, 'corr_length': 0.06494117647058824, 'epsilon': 3, 'epsilon_2': 36, 'rms_high_2': 0.005411764705882353, 'corr_length_2': 0.03952941176470588, 'distance': 0.29411764705882354, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.011294117647058823, 'corr_length': 0.06352941176470589, 'epsilon': 14, 'epsilon_2': 31, 'rms_high_2': 0.010588235294117648, 'corr_length_2': 0.03670588235294118, 'distance': 0.5764705882352941, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.009176470588235295, 'corr_length': 0.06070588235294118, 'epsilon': 11, 'epsilon_2': 22, 'rms_high_2': 0.004941176470588235, 'corr_length_2': 0.026823529411764704, 'distance': 0.34705882352941175, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.006352941176470589, 'corr_length': 0.031058823529411767, 'epsilon': 21, 'epsilon_2': 33, 'rms_high_2': 0.0058823529411764705, 'corr_length_2': 0.03247058823529412, 'distance': 0.6294117647058823, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.004235294117647059, 'corr_length': 0.05223529411764707, 'epsilon': 22, 'epsilon_2': 19, 'rms_high_2': 0.0075294117647058826, 'corr_length_2': 0.024, 'distance': 0.6294117647058823, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.004470588235294118, 'corr_length': 0.031058823529411767, 'epsilon': 33, 'epsilon_2': 15, 'rms_high_2': 0.007764705882352941, 'corr_length_2': 0.05505882352941177, 'distance': 0.43529411764705883, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.011529411764705882, 'corr_length': 0.06917647058823528, 'epsilon': 12, 'epsilon_2': 29, 'rms_high_2': 0.009647058823529411, 'corr_length_2': 0.03529411764705882, 'distance': 0.18823529411764706, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.010588235294117648, 'corr_length': 0.059294117647058824, 'epsilon': 16, 'epsilon_2': 13, 'rms_high_2': 0.009647058823529411, 'corr_length_2': 0.03529411764705882, 'distance': 0.38235294117647056, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.0058823529411764705, 'corr_length': 0.05364705882352941, 'epsilon': 15, 'epsilon_2': 26, 'rms_high_2': 0.006588235294117647, 'corr_length_2': 0.05364705882352941, 'distance': 0.47058823529411764, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.0075294117647058826, 'corr_length': 0.05082352941176471, 'epsilon': 9, 'epsilon_2': 29, 'rms_high_2': 0.00988235294117647, 'corr_length_2': 0.038117647058823534, 'distance': 0.34705882352941175, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.011764705882352941, 'corr_length': 0.029647058823529412, 'epsilon': 22, 'epsilon_2': 21, 'rms_high_2': 0.009411764705882352, 'corr_length_2': 0.0451764705882353, 'distance': 0.5235294117647059, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.004705882352941177, 'corr_length': 0.031058823529411767, 'epsilon': 21, 'epsilon_2': 8, 'rms_high_2': 0.004, 'corr_length_2': 0.046588235294117646, 'distance': 0.5235294117647059, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.00823529411764706, 'corr_length': 0.06635294117647059, 'epsilon': 12, 'epsilon_2': 18, 'rms_high_2': 0.005411764705882353, 'corr_length_2': 0.03529411764705882, 'distance': 0.4, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.008941176470588235, 'corr_length': 0.05647058823529411, 'epsilon': 12, 'epsilon_2': 11, 'rms_high_2': 0.007294117647058824, 'corr_length_2': 0.033882352941176475, 'distance': 0.2235294117647059, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.011764705882352941, 'corr_length': 0.03952941176470588, 'epsilon': 28, 'epsilon_2': 14, 'rms_high_2': 0.004235294117647059, 'corr_length_2': 0.025411764705882356, 'distance': 0.7, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.006823529411764706, 'corr_length': 0.024, 'epsilon': 16, 'epsilon_2': 12, 'rms_high_2': 0.009411764705882352, 'corr_length_2': 0.06917647058823528, 'distance': 0.6470588235294117, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.004470588235294118, 'corr_length': 0.024, 'epsilon': 32, 'epsilon_2': 9, 'rms_high_2': 0.0051764705882352945, 'corr_length_2': 0.07058823529411765, 'distance': 0.20588235294117646, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.011058823529411765, 'corr_length': 0.062117647058823534, 'epsilon': 10, 'epsilon_2': 34, 'rms_high_2': 0.008941176470588235, 'corr_length_2': 0.046588235294117646, 'distance': 0.4, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.004235294117647059, 'corr_length': 0.06635294117647059, 'epsilon': 14, 'epsilon_2': 12, 'rms_high_2': 0.004, 'corr_length_2': 0.03670588235294118, 'distance': 0.31176470588235294, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.004235294117647059, 'corr_length': 0.05647058823529411, 'epsilon': 7, 'epsilon_2': 12, 'rms_high_2': 0.007764705882352941, 'corr_length_2': 0.05505882352941177, 'distance': 0.20588235294117646, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.011529411764705882, 'corr_length': 0.049411764705882356, 'epsilon': 19, 'epsilon_2': 29, 'rms_high_2': 0.005647058823529412, 'corr_length_2': 0.03670588235294118, 'distance': 0.6647058823529411, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.009647058823529411, 'corr_length': 0.07058823529411765, 'epsilon': 24, 'epsilon_2': 7, 'rms_high_2': 0.01011764705882353, 'corr_length_2': 0.06776470588235294, 'distance': 0.17058823529411765, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.006352941176470589, 'corr_length': 0.062117647058823534, 'epsilon': 7, 'epsilon_2': 37, 'rms_high_2': 0.004941176470588235, 'corr_length_2': 0.024, 'distance': 0.5588235294117647, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.004, 'corr_length': 0.02823529411764706, 'epsilon': 26, 'epsilon_2': 29, 'rms_high_2': 0.011058823529411765, 'corr_length_2': 0.03529411764705882, 'distance': 0.5941176470588235, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.007294117647058824, 'corr_length': 0.062117647058823534, 'epsilon': 8, 'epsilon_2': 28, 'rms_high_2': 0.009176470588235295, 'corr_length_2': 0.04376470588235294, 'distance': 0.38235294117647056, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.005411764705882353, 'corr_length': 0.04235294117647059, 'epsilon': 24, 'epsilon_2': 31, 'rms_high_2': 0.008705882352941178, 'corr_length_2': 0.046588235294117646, 'distance': 0.5411764705882353, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.009647058823529411, 'corr_length': 0.07058823529411765, 'epsilon': 30, 'epsilon_2': 5, 'rms_high_2': 0.008941176470588235, 'corr_length_2': 0.05788235294117647, 'distance': 0.6823529411764706, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.01011764705882353, 'corr_length': 0.05082352941176471, 'epsilon': 4, 'epsilon_2': 10, 'rms_high_2': 0.01011764705882353, 'corr_length_2': 0.049411764705882356, 'distance': 0.5235294117647059, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.0058823529411764705, 'corr_length': 0.062117647058823534, 'epsilon': 5, 'epsilon_2': 37, 'rms_high_2': 0.01011764705882353, 'corr_length_2': 0.05647058823529411, 'distance': 0.2588235294117647, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.010352941176470589, 'corr_length': 0.038117647058823534, 'epsilon': 32, 'epsilon_2': 37, 'rms_high_2': 0.011058823529411765, 'corr_length_2': 0.04376470588235294, 'distance': 0.6470588235294117, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.0075294117647058826, 'corr_length': 0.06352941176470589, 'epsilon': 35, 'epsilon_2': 16, 'rms_high_2': 0.010352941176470589, 'corr_length_2': 0.07200000000000001, 'distance': 0.6294117647058823, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.005647058823529412, 'corr_length': 0.046588235294117646, 'epsilon': 18, 'epsilon_2': 10, 'rms_high_2': 0.005647058823529412, 'corr_length_2': 0.026823529411764704, 'distance': 0.5235294117647059, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.004470588235294118, 'corr_length': 0.029647058823529412, 'epsilon': 7, 'epsilon_2': 21, 'rms_high_2': 0.00611764705882353, 'corr_length_2': 0.0451764705882353, 'distance': 0.5764705882352941, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.006823529411764706, 'corr_length': 0.03529411764705882, 'epsilon': 5, 'epsilon_2': 17, 'rms_high_2': 0.010588235294117648, 'corr_length_2': 0.046588235294117646, 'distance': 0.2588235294117647, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.006352941176470589, 'corr_length': 0.024, 'epsilon': 9, 'epsilon_2': 6, 'rms_high_2': 0.00611764705882353, 'corr_length_2': 0.06917647058823528, 'distance': 0.6117647058823529, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.01011764705882353, 'corr_length': 0.07200000000000001, 'epsilon': 13, 'epsilon_2': 15, 'rms_high_2': 0.004235294117647059, 'corr_length_2': 0.046588235294117646, 'distance': 0.41764705882352937, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.006588235294117647, 'corr_length': 0.05647058823529411, 'epsilon': 15, 'epsilon_2': 18, 'rms_high_2': 0.009647058823529411, 'corr_length_2': 0.05788235294117647, 'distance': 0.5411764705882353, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.009647058823529411, 'corr_length': 0.03952941176470588, 'epsilon': 10, 'epsilon_2': 8, 'rms_high_2': 0.006588235294117647, 'corr_length_2': 0.05788235294117647, 'distance': 0.6117647058823529, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.0075294117647058826, 'corr_length': 0.026823529411764704, 'epsilon': 35, 'epsilon_2': 31, 'rms_high_2': 0.007294117647058824, 'corr_length_2': 0.05364705882352941, 'distance': 0.1, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.007294117647058824, 'corr_length': 0.059294117647058824, 'epsilon': 29, 'epsilon_2': 37, 'rms_high_2': 0.008, 'corr_length_2': 0.046588235294117646, 'distance': 0.41764705882352937, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.011764705882352941, 'corr_length': 0.029647058823529412, 'epsilon': 8, 'epsilon_2': 31, 'rms_high_2': 0.005647058823529412, 'corr_length_2': 0.05505882352941177, 'distance': 0.29411764705882354, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.01011764705882353, 'corr_length': 0.04376470588235294, 'epsilon': 8, 'epsilon_2': 34, 'rms_high_2': 0.004, 'corr_length_2': 0.07200000000000001, 'distance': 0.11764705882352941, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.008, 'corr_length': 0.06776470588235294, 'epsilon': 27, 'epsilon_2': 10, 'rms_high_2': 0.008941176470588235, 'corr_length_2': 0.033882352941176475, 'distance': 0.6294117647058823, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.004470588235294118, 'corr_length': 0.02823529411764706, 'epsilon': 27, 'epsilon_2': 22, 'rms_high_2': 0.01011764705882353, 'corr_length_2': 0.06352941176470589, 'distance': 0.13529411764705884, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.010352941176470589, 'corr_length': 0.04235294117647059, 'epsilon': 29, 'epsilon_2': 10, 'rms_high_2': 0.012, 'corr_length_2': 0.046588235294117646, 'distance': 0.1, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.00988235294117647, 'corr_length': 0.02823529411764706, 'epsilon': 23, 'epsilon_2': 8, 'rms_high_2': 0.005647058823529412, 'corr_length_2': 0.05223529411764707, 'distance': 0.4529411764705882, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.0075294117647058826, 'corr_length': 0.03670588235294118, 'epsilon': 5, 'epsilon_2': 14, 'rms_high_2': 0.00611764705882353, 'corr_length_2': 0.07200000000000001, 'distance': 0.32941176470588235, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.00823529411764706, 'corr_length': 0.048, 'epsilon': 35, 'epsilon_2': 29, 'rms_high_2': 0.008470588235294119, 'corr_length_2': 0.048, 'distance': 0.6470588235294117, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.010588235294117648, 'corr_length': 0.05788235294117647, 'epsilon': 21, 'epsilon_2': 6, 'rms_high_2': 0.006823529411764706, 'corr_length_2': 0.05788235294117647, 'distance': 0.5941176470588235, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.009411764705882352, 'corr_length': 0.03247058823529412, 'epsilon': 10, 'epsilon_2': 34, 'rms_high_2': 0.006823529411764706, 'corr_length_2': 0.05647058823529411, 'distance': 0.20588235294117646, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.011764705882352941, 'corr_length': 0.03670588235294118, 'epsilon': 10, 'epsilon_2': 12, 'rms_high_2': 0.0058823529411764705, 'corr_length_2': 0.02823529411764706, 'distance': 0.3647058823529412, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.008705882352941178, 'corr_length': 0.031058823529411767, 'epsilon': 19, 'epsilon_2': 4, 'rms_high_2': 0.008470588235294119, 'corr_length_2': 0.04094117647058823, 'distance': 0.5058823529411764, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.01011764705882353, 'corr_length': 0.031058823529411767, 'epsilon': 34, 'epsilon_2': 30, 'rms_high_2': 0.0058823529411764705, 'corr_length_2': 0.0451764705882353, 'distance': 0.6823529411764706, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.011058823529411765, 'corr_length': 0.026823529411764704, 'epsilon': 34, 'epsilon_2': 5, 'rms_high_2': 0.006588235294117647, 'corr_length_2': 0.05788235294117647, 'distance': 0.5941176470588235, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.004470588235294118, 'corr_length': 0.07058823529411765, 'epsilon': 36, 'epsilon_2': 16, 'rms_high_2': 0.00611764705882353, 'corr_length_2': 0.02823529411764706, 'distance': 0.17058823529411765, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.004470588235294118, 'corr_length': 0.06070588235294118, 'epsilon': 17, 'epsilon_2': 20, 'rms_high_2': 0.00611764705882353, 'corr_length_2': 0.06776470588235294, 'distance': 0.41764705882352937, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.007058823529411765, 'corr_length': 0.024, 'epsilon': 8, 'epsilon_2': 10, 'rms_high_2': 0.007294117647058824, 'corr_length_2': 0.02823529411764706, 'distance': 0.6470588235294117, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.008705882352941178, 'corr_length': 0.03670588235294118, 'epsilon': 6, 'epsilon_2': 5, 'rms_high_2': 0.007764705882352941, 'corr_length_2': 0.06635294117647059, 'distance': 0.5411764705882353, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.009411764705882352, 'corr_length': 0.05505882352941177, 'epsilon': 18, 'epsilon_2': 27, 'rms_high_2': 0.011294117647058823, 'corr_length_2': 0.049411764705882356, 'distance': 0.47058823529411764, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.005411764705882353, 'corr_length': 0.05647058823529411, 'epsilon': 6, 'epsilon_2': 27, 'rms_high_2': 0.012, 'corr_length_2': 0.0451764705882353, 'distance': 0.41764705882352937, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.006352941176470589, 'corr_length': 0.06070588235294118, 'epsilon': 34, 'epsilon_2': 8, 'rms_high_2': 0.006823529411764706, 'corr_length_2': 0.04094117647058823, 'distance': 0.3647058823529412, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.004, 'corr_length': 0.03670588235294118, 'epsilon': 20, 'epsilon_2': 22, 'rms_high_2': 0.01011764705882353, 'corr_length_2': 0.049411764705882356, 'distance': 0.11764705882352941, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.0075294117647058826, 'corr_length': 0.0451764705882353, 'epsilon': 15, 'epsilon_2': 12, 'rms_high_2': 0.00823529411764706, 'corr_length_2': 0.046588235294117646, 'distance': 0.32941176470588235, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.012, 'corr_length': 0.062117647058823534, 'epsilon': 7, 'epsilon_2': 8, 'rms_high_2': 0.00611764705882353, 'corr_length_2': 0.059294117647058824, 'distance': 0.2235294117647059, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.005647058823529412, 'corr_length': 0.07200000000000001, 'epsilon': 35, 'epsilon_2': 27, 'rms_high_2': 0.007058823529411765, 'corr_length_2': 0.05505882352941177, 'distance': 0.29411764705882354, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.004, 'corr_length': 0.06776470588235294, 'epsilon': 37, 'epsilon_2': 4, 'rms_high_2': 0.008470588235294119, 'corr_length_2': 0.07200000000000001, 'distance': 0.5941176470588235, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.011529411764705882, 'corr_length': 0.062117647058823534, 'epsilon': 26, 'epsilon_2': 20, 'rms_high_2': 0.008470588235294119, 'corr_length_2': 0.024, 'distance': 0.41764705882352937, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.004235294117647059, 'corr_length': 0.026823529411764704, 'epsilon': 32, 'epsilon_2': 6, 'rms_high_2': 0.008470588235294119, 'corr_length_2': 0.05788235294117647, 'distance': 0.1, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.011764705882352941, 'corr_length': 0.04376470588235294, 'epsilon': 20, 'epsilon_2': 36, 'rms_high_2': 0.004, 'corr_length_2': 0.029647058823529412, 'distance': 0.6117647058823529, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.006352941176470589, 'corr_length': 0.06494117647058824, 'epsilon': 35, 'epsilon_2': 14, 'rms_high_2': 0.004, 'corr_length_2': 0.05647058823529411, 'distance': 0.5764705882352941, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.004941176470588235, 'corr_length': 0.03529411764705882, 'epsilon': 8, 'epsilon_2': 24, 'rms_high_2': 0.009647058823529411, 'corr_length_2': 0.025411764705882356, 'distance': 0.4, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.00988235294117647, 'corr_length': 0.05223529411764707, 'epsilon': 37, 'epsilon_2': 21, 'rms_high_2': 0.011529411764705882, 'corr_length_2': 0.06917647058823528, 'distance': 0.20588235294117646, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.010352941176470589, 'corr_length': 0.05364705882352941, 'epsilon': 34, 'epsilon_2': 11, 'rms_high_2': 0.006352941176470589, 'corr_length_2': 0.04376470588235294, 'distance': 0.7, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.012, 'corr_length': 0.06352941176470589, 'epsilon': 4, 'epsilon_2': 6, 'rms_high_2': 0.009411764705882352, 'corr_length_2': 0.02823529411764706, 'distance': 0.6823529411764706, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.005411764705882353, 'corr_length': 0.07058823529411765, 'epsilon': 14, 'epsilon_2': 12, 'rms_high_2': 0.005647058823529412, 'corr_length_2': 0.06070588235294118, 'distance': 0.11764705882352941, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.008705882352941178, 'corr_length': 0.0451764705882353, 'epsilon': 22, 'epsilon_2': 12, 'rms_high_2': 0.004470588235294118, 'corr_length_2': 0.046588235294117646, 'distance': 0.29411764705882354, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.010352941176470589, 'corr_length': 0.03952941176470588, 'epsilon': 14, 'epsilon_2': 16, 'rms_high_2': 0.004235294117647059, 'corr_length_2': 0.048, 'distance': 0.6117647058823529, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.008, 'corr_length': 0.048, 'epsilon': 20, 'epsilon_2': 11, 'rms_high_2': 0.004705882352941177, 'corr_length_2': 0.06917647058823528, 'distance': 0.5764705882352941, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.00988235294117647, 'corr_length': 0.026823529411764704, 'epsilon': 17, 'epsilon_2': 3, 'rms_high_2': 0.006823529411764706, 'corr_length_2': 0.02823529411764706, 'distance': 0.13529411764705884, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.007764705882352941, 'corr_length': 0.03670588235294118, 'epsilon': 37, 'epsilon_2': 28, 'rms_high_2': 0.006823529411764706, 'corr_length_2': 0.026823529411764704, 'distance': 0.4882352941176471, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.007058823529411765, 'corr_length': 0.04235294117647059, 'epsilon': 23, 'epsilon_2': 17, 'rms_high_2': 0.00988235294117647, 'corr_length_2': 0.06635294117647059, 'distance': 0.5411764705882353, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.012, 'corr_length': 0.038117647058823534, 'epsilon': 13, 'epsilon_2': 14, 'rms_high_2': 0.005411764705882353, 'corr_length_2': 0.031058823529411767, 'distance': 0.20588235294117646, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.00988235294117647, 'corr_length': 0.048, 'epsilon': 12, 'epsilon_2': 25, 'rms_high_2': 0.007764705882352941, 'corr_length_2': 0.024, 'distance': 0.6470588235294117, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.007058823529411765, 'corr_length': 0.024, 'epsilon': 9, 'epsilon_2': 32, 'rms_high_2': 0.009176470588235295, 'corr_length_2': 0.059294117647058824, 'distance': 0.29411764705882354, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.009176470588235295, 'corr_length': 0.038117647058823534, 'epsilon': 17, 'epsilon_2': 8, 'rms_high_2': 0.008941176470588235, 'corr_length_2': 0.05364705882352941, 'distance': 0.6823529411764706, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.009411764705882352, 'corr_length': 0.02823529411764706, 'epsilon': 12, 'epsilon_2': 5, 'rms_high_2': 0.00611764705882353, 'corr_length_2': 0.03952941176470588, 'distance': 0.6647058823529411, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.004705882352941177, 'corr_length': 0.048, 'epsilon': 35, 'epsilon_2': 13, 'rms_high_2': 0.010352941176470589, 'corr_length_2': 0.03952941176470588, 'distance': 0.18823529411764706, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.008705882352941178, 'corr_length': 0.04235294117647059, 'epsilon': 3, 'epsilon_2': 17, 'rms_high_2': 0.007058823529411765, 'corr_length_2': 0.07058823529411765, 'distance': 0.6294117647058823, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.006588235294117647, 'corr_length': 0.059294117647058824, 'epsilon': 19, 'epsilon_2': 34, 'rms_high_2': 0.00823529411764706, 'corr_length_2': 0.026823529411764704, 'distance': 0.5764705882352941, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.009411764705882352, 'corr_length': 0.06635294117647059, 'epsilon': 28, 'epsilon_2': 26, 'rms_high_2': 0.006823529411764706, 'corr_length_2': 0.04094117647058823, 'distance': 0.32941176470588235, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.0058823529411764705, 'corr_length': 0.05788235294117647, 'epsilon': 16, 'epsilon_2': 36, 'rms_high_2': 0.008705882352941178, 'corr_length_2': 0.038117647058823534, 'distance': 0.5588235294117647, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.0075294117647058826, 'corr_length': 0.07058823529411765, 'epsilon': 31, 'epsilon_2': 33, 'rms_high_2': 0.011764705882352941, 'corr_length_2': 0.062117647058823534, 'distance': 0.6823529411764706, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.011294117647058823, 'corr_length': 0.031058823529411767, 'epsilon': 27, 'epsilon_2': 22, 'rms_high_2': 0.011764705882352941, 'corr_length_2': 0.06070588235294118, 'distance': 0.4, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.009176470588235295, 'corr_length': 0.02823529411764706, 'epsilon': 15, 'epsilon_2': 28, 'rms_high_2': 0.0075294117647058826, 'corr_length_2': 0.07058823529411765, 'distance': 0.5058823529411764, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
# ...
#  {'rms_high': 0.011058823529411765, 'corr_length': 0.033882352941176475, 'epsilon': 36, 'epsilon_2': 10, 'rms_high_2': 0.008, 'corr_length_2': 0.06352941176470589, 'distance': 0.17058823529411765, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.0058823529411764705, 'corr_length': 0.046588235294117646, 'epsilon': 8, 'epsilon_2': 27, 'rms_high_2': 0.006588235294117647, 'corr_length_2': 0.046588235294117646, 'distance': 0.6823529411764706, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.012, 'corr_length': 0.025411764705882356, 'epsilon': 25, 'epsilon_2': 3, 'rms_high_2': 0.005411764705882353, 'corr_length_2': 0.06635294117647059, 'distance': 0.13529411764705884, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.011058823529411765, 'corr_length': 0.06494117647058824, 'epsilon': 13, 'epsilon_2': 31, 'rms_high_2': 0.004470588235294118, 'corr_length_2': 0.03670588235294118, 'distance': 0.29411764705882354, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.011058823529411765, 'corr_length': 0.062117647058823534, 'epsilon': 37, 'epsilon_2': 21, 'rms_high_2': 0.008, 'corr_length_2': 0.04376470588235294, 'distance': 0.3647058823529412, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.011294117647058823, 'corr_length': 0.03247058823529412, 'epsilon': 23, 'epsilon_2': 29, 'rms_high_2': 0.007764705882352941, 'corr_length_2': 0.031058823529411767, 'distance': 0.5764705882352941, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.00823529411764706, 'corr_length': 0.029647058823529412, 'epsilon': 15, 'epsilon_2': 9, 'rms_high_2': 0.01011764705882353, 'corr_length_2': 0.04235294117647059, 'distance': 0.31176470588235294, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.007058823529411765, 'corr_length': 0.04094117647058823, 'epsilon': 21, 'epsilon_2': 9, 'rms_high_2': 0.011764705882352941, 'corr_length_2': 0.04094117647058823, 'distance': 0.34705882352941175, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.00988235294117647, 'corr_length': 0.024, 'epsilon': 15, 'epsilon_2': 23, 'rms_high_2': 0.006823529411764706, 'corr_length_2': 0.031058823529411767, 'distance': 0.41764705882352937, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.011294117647058823, 'corr_length': 0.031058823529411767, 'epsilon': 23, 'epsilon_2': 16, 'rms_high_2': 0.008941176470588235, 'corr_length_2': 0.06352941176470589, 'distance': 0.47058823529411764, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.004941176470588235, 'corr_length': 0.06494117647058824, 'epsilon': 26, 'epsilon_2': 8, 'rms_high_2': 0.009411764705882352, 'corr_length_2': 0.04235294117647059, 'distance': 0.2235294117647059, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.007294117647058824, 'corr_length': 0.07058823529411765, 'epsilon': 13, 'epsilon_2': 14, 'rms_high_2': 0.004, 'corr_length_2': 0.049411764705882356, 'distance': 0.2588235294117647, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.004705882352941177, 'corr_length': 0.05364705882352941, 'epsilon': 24, 'epsilon_2': 17, 'rms_high_2': 0.00611764705882353, 'corr_length_2': 0.06352941176470589, 'distance': 0.29411764705882354, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.00988235294117647, 'corr_length': 0.059294117647058824, 'epsilon': 37, 'epsilon_2': 11, 'rms_high_2': 0.008705882352941178, 'corr_length_2': 0.06070588235294118, 'distance': 0.5588235294117647, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.006588235294117647, 'corr_length': 0.03247058823529412, 'epsilon': 20, 'epsilon_2': 4, 'rms_high_2': 0.005647058823529412, 'corr_length_2': 0.03529411764705882, 'distance': 0.31176470588235294, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.006588235294117647, 'corr_length': 0.024, 'epsilon': 5, 'epsilon_2': 13, 'rms_high_2': 0.010588235294117648, 'corr_length_2': 0.031058823529411767, 'distance': 0.2411764705882353, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.008705882352941178, 'corr_length': 0.07200000000000001, 'epsilon': 20, 'epsilon_2': 19, 'rms_high_2': 0.011058823529411765, 'corr_length_2': 0.06776470588235294, 'distance': 0.4, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.006823529411764706, 'corr_length': 0.026823529411764704, 'epsilon': 23, 'epsilon_2': 3, 'rms_high_2': 0.008470588235294119, 'corr_length_2': 0.029647058823529412, 'distance': 0.3647058823529412, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.009411764705882352, 'corr_length': 0.05364705882352941, 'epsilon': 15, 'epsilon_2': 16, 'rms_high_2': 0.006823529411764706, 'corr_length_2': 0.029647058823529412, 'distance': 0.17058823529411765, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.012, 'corr_length': 0.04376470588235294, 'epsilon': 6, 'epsilon_2': 16, 'rms_high_2': 0.0058823529411764705, 'corr_length_2': 0.06776470588235294, 'distance': 0.13529411764705884, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.007294117647058824, 'corr_length': 0.05788235294117647, 'epsilon': 3, 'epsilon_2': 21, 'rms_high_2': 0.004941176470588235, 'corr_length_2': 0.05647058823529411, 'distance': 0.4529411764705882, 'two_layer': True}
#   warn(
# /home/jotavecorta/proyectos/tesis/src/deep_scattering_models/data/create_data.py:157: RuntimeWarning: La Matriz T no satisface las hipótesis de Cholesky para los parámetros
#  {'rms_high': 0.011294117647058823, 'corr_length': 0.062117647058823534, 'epsilon': 15, 'epsilon_2': 10, 'rms_high_2': 0.007294117647058824, 'corr_length_2': 0.02823529411764706, 'distance': 0.5058823529411764, 'two_layer': True}
#   warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_10901/2117775366.py in <module>
#       1 # Generamos los datos
# ----> 2 noise_data = make_data(noise=True)
#       3
#       4 # Guardamos los datos en data
#       5 file_name = "raw/spm_signatures_noise"
#
# ~/proyectos/tesis/src/deep_scattering_models/data/create_data.py in make_data(realizations, noise, size, **kwargs)
#     147         surface = SpmSurface(**surf_parameters)
#     148         try:
# --> 149             signature = surface.polarization_signature(
#     150                 lambda_,
#     151                 theta,
#
# ~/proyectos/tesis/src/deep_scattering_models/small_perturbation_method/t_matrix.py in polarization_signature(self, lambda_, theta_inc, phi_inc, grid_size, second_order, wishard_noise, **int_kw)
#     821         # Incident wave vector
#     822         k = 2*np.pi/lambda_
# --> 823
#     824         # Mueller matrix
#     825         m_matrix = self.mueller_matrix(
#
# ~/proyectos/tesis/src/deep_scattering_models/small_perturbation_method/t_matrix.py in mueller_matrix(self, lambda_, theta_inc, phi_inc, second_order, noise, **int_kw)
#     722         # Incident wave number
#     723         k = 2 * np.pi / lambda_
# --> 724
#     725         # Coherence T-Matrix
#     726         T = self.t_matrix(
#
# ~/proyectos/tesis/src/deep_scattering_models/small_perturbation_method/t_matrix.py in t_matrix(self, lambda_, theta_inc, phi_inc, second_order, noise, **int_kw)
#     635         # Add second order terms
#     636         if second_order:
# --> 637             amps_dict = self._spm2_integration(
#     638                 lambda_, theta_inc, phi_inc, **int_kw
#     639                 )
#
# ~/proyectos/tesis/src/deep_scattering_models/small_perturbation_method/t_matrix.py in _spm2_integration(self, lambda_, theta_inc, phi_inc, n, lim)
#     518
#     519         # Scattering amplitudes
# --> 520         amps_dict = self._spm2_s_matrix(lambda_, theta_inc, phi_inc, n, lim)
#     521
#     522         S_hh, S_vv, S_hh_S_vv = amps_dict['co-pol']
#
# ~/proyectos/tesis/src/deep_scattering_models/small_perturbation_method/t_matrix.py in _spm2_s_matrix(self, lambda_, theta_inc, phi_inc, n, lim)
#     382
#     383         # Second term (evaluated on k - k_i - k')
# --> 384         amps_st = self._spm2_amplitudes(
#     385             lambda_, theta_inc, phi_inc,
#     386             (k_sx + k_x - kr_x, k_sy + k_y - kr_y)
#
# ~/proyectos/tesis/src/deep_scattering_models/small_perturbation_method/t_matrix.py in _spm2_amplitudes(self, lambda_, theta_inc, phi_inc, int_arguments)
#     187             f01_vv = L0_11VV(k, theta_s, phi_s, theta_inc,
#     188                              phi_inc, self.ep_1, self.ep_2, self.d)
# --> 189             f1_vv = L1_11VV(x, y, k, theta_s, phi_s, theta_inc,
#     190                             phi_inc, self.ep_1, self.ep_2, self.d)
#     191
#
# ~/proyectos/tesis/src/deep_scattering_models/small_perturbation_method/spm2.py in L1_11VV(sx, sy, k0, th, ph, thi, phi, ep1, ep2, d)
#    1017 def L1_11VV(sx,sy,k0,th,ph,thi,phi,ep1,ep2,d):
#    1018     return  (kr(k0,th)*(-((k2z(k0,th,ep2)*ep1 + k1z(k0,th,ep1)*ep2)*(k0*ep1*(ky(k0,th,ph)*q1TM_F1(sx,sy,k0,th,ph,thi,phi,ep1,ep2,d)- kx(k0,th,ph)*q2TM_F1(sx,sy,k0,th,ph,thi,phi,ep1,ep2,d)) + k1z(k0,th,ep1)*(kx(k0,th,ph)*q3TM_F1(sx,sy,k0,th,ph,thi,phi,ep1,ep2,d) + ky(k0,th,ph)*q4TM_F1(sx,sy,k0,th,ph,thi,phi,ep1,ep2,d)))) + \
# -> 1019             exp(2*1j*d*k1z(k0,th,ep1))*(-(k2z(k0,th,ep2)*ep1) + k1z(k0,th,ep1)*ep2)*(k0*ep1*(-(ky(k0,th,ph)*q1TM_F1(sx,sy,k0,th,ph,thi,phi,ep1,ep2,d)) + kx(k0,th,ph)*q2TM_F1(sx,sy,k0,th,ph,thi,phi,ep1,ep2,d)) + k1z(k0,th,ep1)*(kx(k0,th,ph)*q3TM_F1(sx,sy,k0,th,ph,thi,phi,ep1,ep2,d) + ky(k0,th,ph)*q4TM_F1(sx,sy,k0,th,ph,thi,phi,ep1,ep2,d)))))/\
#    1020             ((kx(k0,th,ph)**2 + ky(k0,th,ph)**2)*(exp(2*1j*d*k1z(k0,th,ep1))*(k1z(k0,th,ep1) - k0z(k0,th)*ep1)*(-(k2z(k0,th,ep2)*ep1) + k1z(k0,th,ep1)*ep2) - (k1z(k0,th,ep1) + k0z(k0,th)*ep1)*(k2z(k0,th,ep2)*ep1 + k1z(k0,th,ep1)*ep2)))
#    1021
#
# ~/proyectos/tesis/src/deep_scattering_models/small_perturbation_method/spm2.py in q1TM_F1(sx, sy, k0, th, ph, thi, phi, ep1, ep2, d)
#     648
#     649 def q1TM_F1(sx,sy,k0,th,ph,thi,phi,ep1,ep2,d):
# --> 650     return L11TM(sx,sy,k0,th,ph,thi,phi,ep1,ep2,d) + Y1TM_F1(sx,sy,k0,th,ph,thi,phi,ep1,ep2,d)
#     651
#     652 #--F2
#
# ~/proyectos/tesis/src/deep_scattering_models/small_perturbation_method/spm2.py in Y1TM_F1(sx, sy, k0, th, ph, thi, phi, ep1, ep2, d)
#     645 def Y1TM_F1(sx,sy,k0,th,ph,thi,phi,ep1,ep2,d):
#     646     return -1j*s0z(k0,sx,sy)*((a1HVF1(k0,thi,phi,th,ph,ep1,ep2,d)*sx)/sr(sx,sy) + (a1VVF1(k0,thi,phi,th,ph,ep1,ep2,d)*s0z(k0,sx,sy)*sy)/(k0*sr(sx,sy))) + (1j*a1VVF1(k0,thi,phi,th,ph,ep1,ep2,d)*(ky(k0,th,ph) - sy)*sr(sx,sy))/k0 - 1j*s1z(k0,sx,sy,ep1)*((b1HVF1(k0,thi,phi,th,ph,ep1,ep2,d)*sx)/sr(sx,sy) - (b1VVF1(k0,thi,phi,th,ph,ep1,ep2,d)*s1z(k0,sx,sy,ep1)*sy)/(k0*sr(sx,sy)*sqrt(ep1)))+\
# --> 647             1j*s1z(k0,sx,sy,ep1)*((bb1HVF1(k0,thi,phi,th,ph,ep1,ep2,d)*sx)/sr(sx,sy) + (bb1VVF1(k0,thi,phi,th,ph,ep1,ep2,d)*s1z(k0,sx,sy,ep1)*sy)/(k0*sr(sx,sy)*sqrt(ep1))) - (1j*b1VVF1(k0,thi,phi,th,ph,ep1,ep2,d)*(ky(k0,th,ph) - sy)*sr(sx,sy))/(k0*sqrt(ep1)) - (1j*bb1VVF1(k0,thi,phi,th,ph,ep1,ep2,d)*(ky(k0,th,ph) - sy)*sr(sx,sy))/(k0*sqrt(ep1))
#     648
#     649 def q1TM_F1(sx,sy,k0,th,ph,thi,phi,ep1,ep2,d):
#
# ~/proyectos/tesis/src/deep_scattering_models/small_perturbation_method/spm2.py in bb1HVF1(k0, thi, phi, th, ph, ep1, ep2, d)
#     344 def bb1HVF1(k0,thi,phi,th,ph,ep1,ep2,d):
#     345     return -1j*((exp(1j*d*(k1z(k0,th,ep1) - k1zi(k0,thi,ep1)) + 1j*d*(k1z(k0,th,ep1) + k1zi(k0,thi,ep1)))*(k1z(k0,th,ep1) - k2z(k0,th,ep2))*(kiy(k0,thi,phi)*kx(k0,th,ph) - kix(k0,thi,phi)*ky(k0,th,ph))*kr(k0,th)*\
# --> 346              ((bb0VV(k0,thi,ep1,ep2,d) + b0VV(k0,thi,ep1,ep2,d))*k0z(k0,th)*(k1zi(k0,thi,ep1)**2 + kir(k0,thi)**2) + (-1 + a0VV(k0,thi,ep1,ep2,d))*kiz(k0,thi)*sqrt(ep1) - (1 + a0VV(k0,thi,ep1,ep2,d))*k0z(k0,th)*(kiz(k0,thi)**2 + kir(k0,thi)**2)*sqrt(ep1) + (-(bb0VV(k0,thi,ep1,ep2,d)*k1z(k0,th,ep1)) + b0VV(k0,thi,ep1,ep2,d)*k1zi(k0,thi,ep1))*ep1))/\
#     347              ((exp(2*1j*d*k1z(k0,th,ep1))*(k0z(k0,th) - k1z(k0,th,ep1))*(k1z(k0,th,ep1) - k2z(k0,th,ep2)) + (k0z(k0,th) + k1z(k0,th,ep1))*(k1z(k0,th,ep1) + k2z(k0,th,ep2)))*kir(k0,thi)*(kx(k0,th,ph)**2 + ky(k0,th,ph)**2)*sqrt(ep1)))
#     348
#
# ~/proyectos/tesis/src/deep_scattering_models/small_perturbation_method/spm2.py in a0VV(k0, thi, ep1, ep2, d)
#     104 ## CANAL VV ##
#     105 def a0VV(k0,thi,ep1,ep2,d):
# --> 106     return (-1j*k1zi(k0,thi,ep1)*ep1*(k2zi(k0,thi,ep2) - kiz(k0,thi)*ep2)*cos(d*k1zi(k0,thi,ep1)) + (k2zi(k0,thi,ep2)*kiz(k0,thi)*ep1**2 - k1zi(k0,thi,ep1)**2*ep2)*sin(d*k1zi(k0,thi,ep1)))/(1j*k1zi(k0,thi,ep1)*ep1*(k2zi(k0,thi,ep2) + kiz(k0,thi)*ep2)*cos(d*k1zi(k0,thi,ep1)) + (k2zi(k0,thi,ep2)*kiz(k0,thi)*ep1**2 + k1zi(k0,thi,ep1)**2*ep2)*sin(d*k1zi(k0,thi,ep1)))
#     107
#     108 def bb0VV(k0,thi,ep1,ep2,d):
#
# ~/proyectos/tesis/src/deep_scattering_models/small_perturbation_method/spm2.py in k1zi(k0, thi, ep1)
#      46
#      47 def k1zi(k0,thi,ep1):
# ---> 48     return k0*sqrt(ep1-sin(thi)**2)
#      49
#      50 def k2zi(k0,thi,ep2):
#
# KeyboardInterrupt:

# %%
noise_data = load_data("raw/spm_signatures_noise")

# %% [markdown]
# Nuevamente, elijamos una firma al azar y veamos qué pinta tiene.

# %%
# Elegimos ana firma al azar
rng = np.random.default_rng()
rnd_index = rng.integers(20048)
rnd_signature = noise_data[rnd_index, :, :]

# Ploteamos
plot_polarization_signature(rnd_signature)
# Out:
# <AxesSubplot:title={'center':'$\\sigma(\\psi,\\chi)$'}, xlabel='Orientation Angle $\\psi$ [°]', ylabel='Ellipticity Angle $\\chi$ [°]'>

# %% [markdown]
# Transformemos a dB y miremos la distribución de los datos, que no debería cambiar por el agregado de ruido.

# %%
noised_data_dB = to_dB(
    remove_outliers(noise_data)
    )
ax = plot_histogram(noised_data_dB)
ax.set_xlabel(r"$\sigma(\psi, \chi)$ [dB]")
